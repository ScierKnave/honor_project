# %%
# Hardware hyperparameters
chosen_device = torch.device('cuda' 
if torch.cuda.is_available() else 'cpu')

# Data hyperparameters
nb_train = 2000
nb_test = 500
chosen_bs = 150
chosen_bs = min(nb_train, chosen_bs)
nb_classes = 10

# Teacher hyperparameters
chosen_device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
n_epochs_fcnn = 15
hidden_size = 70
chosen_loss = nn.CrossEntropyLoss()
#Optimizer parameters
chosen_lr = 0.0001
chosen_momentum = 0.9

# Student hyperparameters
# MPS parameters
bond_dim = 20
adaptive_mode = False
periodic_bc = False
feature_map = lambda x : torch.tensor([1, x]).to(chosen_device)
# Training parameters
gauss_epochs = 5 # number of epochs with added gaussian noise
gn_var = 0.3 #added gaussian noise variance
gn_mean = 0 #added gaussian noise mean
n_epochs_lmps = 15
mps_learn_rate = 0.0001
mps_reg = 0.0
mps_chosen_loss = nn.KLDivLoss(reduction = "batchmean", log_target = True)


The teacher's accuracy score is:
tensor(0.6161)

1.3831590414047241
1.1819764375686646
0.8108365535736084
0.9503380656242371
0.7123497128486633
0.34388285875320435
0.27501872181892395
0.2565295696258545
0.2047765552997589
0.21274572610855103
0.14465166628360748
1.1209607124328613
1.2415777444839478
0.8978991508483887
0.905803918838501
Student_acc_score:
tensor(0.2740)
